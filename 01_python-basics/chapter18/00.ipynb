# %%
student = {
    "name": "민수",
    "score": 85,
}

def show_result(student):
    print(f"{student['name']}의 점수는 {student['score']}점입니다.")

show_result(student)
# Out:
# 민수의 점수는 85점입니다.

# %%
class Student:
    pass #아무 내용도 쓰지 않을 때 pass 를 써야 한다

student1 = Student()
student2 = Student()

print(student1 is student2)
# Out:
# False

# %%
class Student:
    pass

student1 = Student()

print(student1)
print(type(student1))
# Out:
# ...
# <class '__main__.Student'>

# %%
class Student:
    def __init__(self, name, score):
        self.name = name
        self.score = score

# %%
student1 = Student("민수", 85)

# %%
student1.score +=1

print(student1.score)
# Out:
# 86

# %%
class Student:
    def __init__(self, name, score):
        self.name = name
        self.score = score

    def show_result(self):
        print(f"{self.name}: {self.score}점")

    def is_passed(self):
        return self.score >= 60

# %%
student1 = student("홍길동", 75)
student2 = student("호랭이", 45)
student3 = student("라꿍이", 88)

student = [student1,student2,student3]

for student in student:
    print(f"{student.name}님의 점수는 {student.score}점 입니다")
    result = ""

if student.is_passed()==True:
    result = "당당히 합격"
else:
    result = "아쉽지만 탈락"

print(f"{student.name}님은 이번 시험에서 {result} 했습니다.")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 student1 = student("홍길동", 75)
#       2 student2 = student("호랭이", 45)
#       3 student3 = student("라꿍이", 88)
#       4
#
# TypeError: 'Student' object is not callable
