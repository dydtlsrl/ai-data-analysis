# %%
import math_tools

print(math_tools.add(10, 20))
print(math_tools.average([80, 90, 100, 70,30]))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 3
#       1 import math_tools
#       2
# ----> 3 print(math_tools.add(10, 20))
#       4 print(math_tools.average([80, 90, 100, 70,30]))
#
# AttributeError: module 'math_tools' has no attribute 'add'
