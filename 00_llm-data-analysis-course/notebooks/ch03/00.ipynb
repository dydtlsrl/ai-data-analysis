# %%
import pandas as pd

orders = pd.read_csv("../../data/raw/orders.csv")

# %%
print(orders.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   order_id        301 non-null    int64
#  1   customer_id     301 non-null    int64
#  2   order_date      301 non-null    str
#  3   payment_method  301 non-null    str
#  4   order_status    301 non-null    str
# dtypes: int64(2), str(3)
# memory usage: 20.0 KB
# None

# %%
print(orders.head())
# Out:
#    order_id  customer_id  order_date payment_method order_status
# 0         1          123  2026-06-03           card    completed
# 1         2           77  2025-08-19      naver_pay    cancelled
# 2         3          138  2025-12-16  bank_transfer    cancelled
# 3         4           57  2026-02-26      kakao_pay    cancelled
# 4         5          125  2026-01-17           card    cancelled

# %%
print(orders.index)

df=orders[["customer_id", "order_id"]]
print(type(df))
# Out:
# RangeIndex(start=0, stop=301, step=1)
# <class 'pandas.DataFrame'>

# %%
df=orders[["customer_id", "order_id"]]
print(type(df))
print(df)
# Out:
# <class 'pandas.DataFrame'>
#      customer_id  order_id
# 0            123         1
# 1             77         2
# 2            138         3
# 3             57         4
# 4            125         5
# ..           ...       ...
# 296           22       297
# 297           64       298
# 298          135       299
# 299           96       300
# 300          300       321
#
# [301 rows x 2 columns]

# %%
orders["order_date"].dtype

converted = pd.to_numeric(orders["order_id"], errors="coerce")

# %%
print(orders.describe())
# Out:
#          order_id  customer_id
# count  301.000000   301.000000
# mean   151.066445    80.222591
# std     87.157877    45.518278
# min      1.000000     3.000000
# 25%     76.000000    38.000000
# 50%    151.000000    83.000000
# 75%    226.000000   117.000000
# max    321.000000   300.000000
