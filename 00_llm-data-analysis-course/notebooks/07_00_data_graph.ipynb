# %%
import pandas as pd
import numpy as np

data_dir = "../data/raw"

customers = pd.read_csv("../../data/raw/customers.csv")
order_items = pd.read_csv("../../data/raw/order_items.csv")
orders = pd.read_csv("../../data/raw/orders.csv")
products = pd.read_csv("../../data/raw/products.csv")

# %%
import matplotlib.pyplot as plt

x_data = ['korea', 'japan', 'ollama', 'rollingthunder', 'database']
y_data = [79, 70, 87, 88, 59]


fig, ax = plt.subplots(figsize=(10, 5))
ax.bar(x_data, y_data)
ax.set_title("그래프 제목")
ax.set_xlabel("x축")
ax.set_ylabel("y축")
ax.set_ylim(bottom=0)
fig.tight_layout()
fig.savefig(
    "graph.png",
    dpi=150,
    bbox_inches="tight",
)

plt.show()
# Out:
# C:\Users\dydtl\AppData\Local\Temp\ipykernel_23624\1609883009.py:13: UserWarning: Glyph 52629 (\N{HANGUL SYLLABLE CUG}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\dydtl\AppData\Local\Temp\ipykernel_23624\1609883009.py:13: UserWarning: Glyph 44536 (\N{HANGUL SYLLABLE GEU}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\dydtl\AppData\Local\Temp\ipykernel_23624\1609883009.py:13: UserWarning: Glyph 47000 (\N{HANGUL SYLLABLE RAE}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\dydtl\AppData\Local\Temp\ipykernel_23624\1609883009.py:13: UserWarning: Glyph 54532 (\N{HANGUL SYLLABLE PEU}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\dydtl\AppData\Local\Temp\ipykernel_23624\1609883009.py:13: UserWarning: Glyph 51228 (\N{HANGUL SYLLABLE JE}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\dydtl\AppData\Local\Temp\ipykernel_23624\1609883009.py:13: UserWarning: Glyph 47785 (\N{HANGUL SYLLABLE MOG}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\dydtl\AppData\Local\Temp\ipykernel_23624\1609883009.py:14: UserWarning: Glyph 52629 (\N{HANGUL SYLLABLE CUG}) missing from font(s) DejaVu Sans.
#   fig.savefig(
# C:\Users\dydtl\AppData\Local\Temp\ipykernel_23624\1609883009.py:14: UserWarning: Glyph 44536 (\N{HANGUL SYLLABLE GEU}) missing from font(s) DejaVu Sans.
#   fig.savefig(
# C:\Users\dydtl\AppData\Local\Temp\ipykernel_23624\1609883009.py:14: UserWarning: Glyph 47000 (\N{HANGUL SYLLABLE RAE}) missing from font(s) DejaVu Sans.
#   fig.savefig(
# C:\Users\dydtl\AppData\Local\Temp\ipykernel_23624\1609883009.py:14: UserWarning: Glyph 54532 (\N{HANGUL SYLLABLE PEU}) missing from font(s) DejaVu Sans.
#   fig.savefig(
# C:\Users\dydtl\AppData\Local\Temp\ipykernel_23624\1609883009.py:14: UserWarning: Glyph 51228 (\N{HANGUL SYLLABLE JE}) missing from font(s) DejaVu Sans.
#   fig.savefig(
# C:\Users\dydtl\AppData\Local\Temp\ipykernel_23624\1609883009.py:14: UserWarning: Glyph 47785 (\N{HANGUL SYLLABLE MOG}) missing from font(s) DejaVu Sans.
#   fig.savefig(

# %%
from matplotlib import font_manager

installed_fonts = {font.name for font in font_manager.fontManager.ttflist}
# installed_fonts

font_candidates = ["malgun Gothic", "AppleGothic", "Apple SD Gothic Neo","Noto Sans CJK KR", "NanumGothic"]

# %%
korean_font = []
