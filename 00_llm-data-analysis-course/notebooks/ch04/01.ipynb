# %%
from pathlib import Path
PROJECT_ROOT = Path.cwd()
DATA_DIR = PROJECT_ROOT / "data" / "raw"
print(DATA_DIR)
# Out:
# c:\dev\ai-data-analysis\00_llm-data-analysis-course\notebooks\ch04\data\raw

# %%
    current=Path.cwd().resolve()
    project_root= current
    print("현재 위치:",current)

    while True:

        if (current / "data").is_dir():
            project_root=current
            break

        current=current.parent


    print("프로젝트 루트:", project_root)

    return "프로젝트 루트 경로"
# Out:
# 현재 위치: C:\dev\ai-data-analysis\00_llm-data-analysis-course\notebooks\ch04
# 프로젝트 루트: C:\dev\ai-data-analysis\00_llm-data-analysis-course

# %%
from pathlib import Path

def get_project_root():    
    current=Path.cwd().resolve()
    project_root= current

    while True:
        if (current / "data").is_dir():
            project_root=current
            break
        current=current.parent
    return project_root

#get_data_dir 이라는 함수를 만드시오.
def get_data_dir():
    project_root = get_project_root()
    data_dir = project_root / "data" / "raw"
    return data_dir

print("현제 프로젝트 루트:", get_data_dir())
# Out:
# 현제 프로젝트 루트: C:\dev\ai-data-analysis\00_llm-data-analysis-course\data\raw
